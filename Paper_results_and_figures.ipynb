# %% [markdown]
# # Dynamical error reshaping for dual-rail erasure qubits
#
# ## Filippos Dakis
# Virginia Tech,   Nov 2025
#
# This notebook reproduces the results shown in ["Dynamical error reshaping for dual-rail erasure qubits" arxiv.org/2510.08416](https://arxiv.org/abs/2510.08416). Hence, in order to understand, studying or at least skimming the paper is strongly recommended.
#
# The scope of this notebook is to guide the reader through the results and explain how they where obtained. It is meant to be explamatory and pedagogical, so the reader can start from here and extend this work further. To that end, every code cell, function, and line are followed by comments.
#
# The reader is recommended to run the cells one after the other instead of executing the whole notebook at once.
#
# Any feedback and suggestions are much appreciated!   dakisfilippos@vt.edu

# %%
import numpy as np
import matplotlib.pyplot as plt
import qutip as qt

import tools

import os
os.chdir("/home/filippos-dakis/Documents/Github_Repos/Dual-rail-Erasure-Qubits")

# %%
# Pauli operators
I = qt.qeye(2)
X = qt.sigmax()
Y = qt.sigmay()
Z = qt.sigmaz()


II = qt.tensor(I, I)                                # two-qubit identity gate

# -------------------- Operators acting on CAVITY --------------------
X0 = qt.tensor(X, I)                                # Pauli operators acting on the cavity
Y0 = qt.tensor(Y, I)
Z0 = qt.tensor(Z, I)
# ------------------- Operators acting on TRANSMON -------------------
X1 = qt.tensor(I, X)                                # Pauli operators acting on the transmon/ancilla
Y1 = qt.tensor(I, Y)
Z1 = qt.tensor(I, Z)


N_points  = 2**12                                   # total points for curve/simulation etc

# %% [markdown]
# In the next couple of lines we define the Hamiltonian given in Eq.(1) of ["Dynamical error reshaping for dual-rail erasure qubits"](https://arxiv.org/abs/2510.08416).We will use this Hamiltonian to obtain the joint parity gate, and then compare our results against this two-qubit gate.
#
# Hamiltonian:
# $$ H = \frac{g_{bs}}{2}(a^\dagger b + ab^\dagger) + \frac{\chi}{2}a^\dagger a \sigma_z$$
#
# Beamsplitter coupling strength: $g_{bs} = \frac{\sqrt{3}}{2}|\chi|$,
#
# Gate time: $T_{\rm gate} = 2\pi/|\chi|$
#
# For the derfivation see Appendix E in [Dual-rail encoding with superconducting cavities](https://www.pnas.org/doi/10.1073/pnas.2221736120)

# %%
N_fock = 2        # each cavity holds 0 or 1 photon

# Bosonic operators embedded in cavity_a ⊗ cavity_b ⊗ transmon
a  = qt.tensor(qt.destroy(N_fock), qt.qeye(N_fock), qt.qeye(2))  # annihilation, cavity a
b  = qt.tensor(qt.qeye(N_fock), qt.destroy(N_fock), qt.qeye(2))  # annihilation, cavity b
Sz = qt.tensor(qt.qeye(N_fock), qt.qeye(N_fock), qt.sigmaz())    # transmon sigma_z

# Projectors onto |00> and |11> cavity sectors (with identity on transmon)
P_00 = qt.tensor(qt.basis(N_fock,0)*qt.basis(N_fock,0).dag(), qt.basis(N_fock,0)*qt.basis(N_fock,0).dag(), qt.qeye(2))
P_11 = qt.tensor(qt.basis(N_fock,1)*qt.basis(N_fock,1).dag(), qt.basis(N_fock,1)*qt.basis(N_fock,1).dag(), qt.qeye(2))

# Logical cavity Pauli operators: act as Pauli in {|01>,|10>} code space, identity on |00> and |11>
X_cav = (a.dag()*b + a*b.dag())         + P_00 + P_11
Y_cav = -1j*(a.dag()*b - a*b.dag())     + P_00 + P_11
Z_cav = (a.dag()*a - b.dag()*b)         + P_00 + P_11


chi        = -1                                                  # MHz
g_chi      = (np.sqrt(3)/2) * np.abs(chi)                       # beamsplitter coupling
t_gate_ref = 2*np.pi / np.abs(chi)                              # gate time
t_sqr_pls  = np.linspace(0, t_gate_ref, N_points)               # time vector

# Hamiltonian Eq.(1)
H_sqr_pls = (g_chi/2) * (a.dag()*b + a*b.dag()) - (chi/2) * a.dag()*a * Sz

# Propagator
U_sqr_pls = qt.propagator(H_sqr_pls, t=t_sqr_pls, options={'max_step': 0.1/N_points, 'atol': 1e-14, 'rtol': 1e-14})

U_sqr_pls[-1]
# Out:
# Quantum object: dims=[[2, 2, 2], [2, 2, 2]], shape=(8, 8), type='oper', dtype=Dense, isherm=False
# Qobj data =
# [[ 1.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j
#    0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j
#    0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j
#    0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j]
#  [ 0.00000000e+00+0.00000000e+00j  1.00000000e+00+0.00000000e+00j
#    0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j
#    0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j
#    0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j]
#  [ 0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j
#   -4.89796011e-15+1.00000000e+00j  0.00000000e+00+0.00000000e+00j
#    9.94589888e-12-1.63529078e-15j  0.00000000e+00+0.00000000e+00j
#    0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j]
# ...

# %% [markdown]
# First, we examine the case of zero photons in the cavities, which should lead to an identity gate on transmon, $I_1\otimes I_2$.

# %%
# |00> ⊗ transmon subspace (0 photons)
qt.Qobj(U_sqr_pls[-1][0:2, 0:2])
# Out:
# Quantum object: dims=[[2], [2]], shape=(2, 2), type='oper', dtype=Dense, isherm=True
# Qobj data =
# [[1. 0.]
#  [0. 1.]]

# %% [markdown]
# Second, we examine the case of one photon in the cavities, which should lead to a $Z$ gate on transmon, $I_1\otimes Z_2$.

# %%
# Dual-rail code space {|01>, |10>} ⊗ transmon
qt.Qobj(U_sqr_pls[-1][2:6, 2:6])
# Out:
# Quantum object: dims=[[4], [4]], shape=(4, 4), type='oper', dtype=Dense, isherm=False
# Qobj data =
# [[-4.89796011e-15+1.00000000e+00j  0.00000000e+00+0.00000000e+00j
#    9.94589888e-12-1.63529078e-15j  0.00000000e+00+0.00000000e+00j]
#  [ 0.00000000e+00+0.00000000e+00j -4.89796011e-15-1.00000000e+00j
#    0.00000000e+00+0.00000000e+00j -9.94589888e-12-1.63529078e-15j]
#  [ 9.93500987e-12-1.25144267e-14j  0.00000000e+00+0.00000000e+00j
#    1.14594303e-11+1.00000000e+00j  0.00000000e+00+0.00000000e+00j]
#  [ 0.00000000e+00+0.00000000e+00j -9.93500987e-12-1.25144267e-14j
#    0.00000000e+00+0.00000000e+00j  1.14594303e-11-1.00000000e+00j]]

# %% [markdown]
# Finally, we examine the case of 2 photons in the cavities, which should lead again to an identity gate on transmon, $I_1\otimes I_2$.

# %%
# |11> ⊗ transmon subspace (2 photons)
qt.Qobj(U_sqr_pls[-1][6:8, 6:8])
# Out:
# Quantum object: dims=[[2], [2]], shape=(2, 2), type='oper', dtype=Dense, isherm=False
# Qobj data =
# [[-1.+1.14730283e-11j  0.+0.00000000e+00j]
#  [ 0.+0.00000000e+00j -1.-1.14730283e-11j]]

# %% [markdown]
# As you can see, the above results demonstrate a rotation on the transmon/acilla conditional to the number of photons stored in the cavities. We used a noise-free Hamiltonian for the above gate and thus we achieved a non-demolition parity measurement with fidelity 1. We will see later on how this gate performs in the presence of dephasing noise.

# %% [markdown]
# Before we proceed, one can play a bit with the adjoint representation and see how SU(2) transforms to SO(3).

# %%
# ------ choose the gate in SU(2) representation -------------
n_target   = [0,0,1]                                     # rotation axis 
phi_target = np.pi/2                                     # angle, keep in mind the double cover !!! 
U_target   = tools.expm(n_target, phi_target/2)          # U = exp(1j * phi * n \dot sigma_pauli)


R_target   = tools.adjoint_Representation(U_target)      # R is the adjoint representation

print(" ------------ U_target -----------")
print(U_target)
print(" ---------------------------------\n")

print(" ------------ R_target -----------")
tools.print_matrix_sci(R_target)
print(" ---------------------------------")
# Out:
#  ------------ U_target -----------
# [[0.70710678+0.70710678j 0.        +0.j        ]
#  [0.        +0.j         0.70710678-0.70710678j]]
#  ---------------------------------
#
#  ------------ R_target -----------
# /                                \
# | 2.220e-16  1.000e+00  0.000e+00|
# |-1.000e+00  2.220e-16  0.000e+00|
# | 0.000e+00  0.000e+00  1.000e+00|
# \                                /
#  ---------------------------------

# %% [markdown]
# In order to have dephasing robust gates we came up with a different protocol. Instead of using the above gates, we implement the joint parity unitary as a three-part composite sequence in which each segment cancels dephasing to first order, yielding a dynamically corrected $U_{\rm JP}$ with quartic sensitivity to noise.You can see the steps gate in Figure 1(b).

# %% [markdown]
# The first and third steps are identical. Here we define the conditional $ZZ(\pi/2)$ gate we use in these steps.

# %%
name = 'Rz_pi_2'

print(name,"\n")

cn, ampl, ct, T_g, speed = tools.read_dict(name)                 # read the coefficients from the csv file 

time      = np.linspace(0, T_g, N_points)                        # time vector, T_g is the gate tiem

pulse     = ampl *np.real(tools.f_in_FS(time, cn))               # the curvature, cn are the Fourier coefficients, ampl is a multiplicative coeff as an extra degree of freedom

# control fields
omega = pulse                                                    # driving along X-axis
phi   = 0                                                        # phase field
delta = ct                                                       # detuning, ct is the torsion


T_g_times_chi = 2 * ct * T_g / np.abs(chi)                               # gate time for the ZZ(pi/2) between cavity a and transmon

time_gate_1_3 = np.linspace(0, T_g_times_chi, N_points) 

# normalized parameters w.r.t.  χ  
x_control = omega * chi / (2*ct)                                            # normalized (w.r.t. \chi) control along X-axis                                    
y_control = np.zeros_like(x_control)                                        # normalized (w.r.t. \chi) control along Y-axis
z_control = chi/2                                                           # normalized (w.r.t. \chi) control along Z-axis

plt.plot(time_gate_1_3 * chi, x_control / np.abs(chi), linewidth = 3.)     # plot the pulse 
plt.xlabel("T_g * χ")
plt.ylabel("Ω/χ")
plt.xlim([0,T_g_times_chi * np.abs(chi)])
plt.ylim([-1, 1.20])
# plt.savefig("R_z_pi_4_curvature_wrt_chi.svg")
# Out:
# Rz_pi_2
# (-1.0, 1.2)

# %%
# Additional operators in cavity_a ⊗ cavity_b ⊗ transmon space
Sx  = qt.tensor(qt.qeye(N_fock), qt.qeye(N_fock), qt.sigmax())  # transmon sigma_x
Sy  = qt.tensor(qt.qeye(N_fock), qt.qeye(N_fock), qt.sigmay())  # transmon sigma_y
n_a = a.dag() * a                                               # cavity a photon number
n_b = b.dag() * b                                               # cavity b photon number

g_control = np.zeros_like(x_control)                            # beamsplitter coupling, g=0

# H = (g/2)(a†b + ab†) - (chi/2) n_a Sz + Omega_x/2 Sx + Omega_y/2 Sy + delta/2 Sz
H_robust_step_1_3 = [[n_a * Sz,                   -(chi/2)],
                     [(a.dag()*b + a*b.dag())/2, g_control],
                     [Sx/2,                      x_control],
                     [Sy/2,                      y_control],
                     [Sz/2,                      z_control]]

H_robust_step_1_3 = qt.QobjEvo(H_robust_step_1_3, tlist=time_gate_1_3)

U_step_1_3 = qt.propagator(H_robust_step_1_3, t=time_gate_1_3, args=None,
                              options={"max_step": 0.5/N_points, "atol": 1e-14, "rtol": 1e-14})

U_step_1_3[-1]
# Out:
# Quantum object: dims=[[2, 2, 2], [2, 2, 2]], shape=(8, 8), type='oper', dtype=Dense, isherm=False
# Qobj data =
# [[-7.07106917e-01+7.07106646e-01j -2.53097033e-09+1.11688969e-07j
#    0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j
#    0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j
#    0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j]
#  [ 2.53097033e-09+1.11688969e-07j -7.07106917e-01-7.07106646e-01j
#    0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j
#    0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j
#    0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j]
#  [ 0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j
#   -7.07106917e-01+7.07106646e-01j -2.53097033e-09+1.11688969e-07j
#    0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j
#    0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j]
# ...

# %%
# |00> ⊗ transmon subspace (0 photons)
#qt.Qobj(U_step_1_3[-1][0:2, 0:2])

# Dual-rail code space {|01>, |10>} ⊗ transmon
#qt.Qobj(U_step_1_3[-1][2:6, 2:6])

# |11> ⊗ transmon subspace (2 photons)
#qt.Qobj(U_step_1_3[-1][6:8, 6:8])

# %% [markdown]
# Now let's compute the fidelity of the **Parity measurement** operation when there are **0 photons** in the cavity. That said, the cavities are in the global ground state $\ket{00}$ and so the $X$ operation on the beamsplitter will act as "Identity" on the cavities. In other words, the gate we are interested in is of the form
# $\begin{equation}
#     U_0 = R_{z}(\pi/2) \,\, X_{\rm cav}\,\, R_{z}(\pi/2) = \ket{00}\bra{00}\otimes I_2
# \end{equation}$

# %%
U_sim_1 = U_step_1_3[-1] * (Sz*X_cav) * U_step_1_3[-1]

fid_0 = tools.calculate_gate_fidelity(U_sim_1[0:2, 0:2], I)
print(" ----------------- Infidelity ----------------\n")
print("             ", 1 - fid_0, "\n")
print(" ---------------------------------------------")

qt.Qobj(U_sim_1[0:2, 0:2])
# Out:
#  ----------------- Infidelity ----------------
#
#               9.559020242022598e-14
#
#  ---------------------------------------------
# Quantum object: dims=[[2], [2]], shape=(2, 2), type='oper', dtype=Dense, isherm=False
# Qobj data =
# [[ 3.82973997e-07-1.00000000e+00j -1.57952024e-07-3.57933188e-09j]
#  [-1.57952024e-07+3.57933188e-09j -3.82973998e-07-1.00000000e+00j]]

# %% [markdown]
# Next, we use the **EXACT SAME GATE** for the single-photon subspace.

# %%
qt.Qobj(U_step_1_3[-1][2:6,2:6])
# Out:
# Quantum object: dims=[[4], [4]], shape=(4, 4), type='oper', dtype=Dense, isherm=False
# Qobj data =
# [[-7.07106917e-01+7.07106646e-01j -2.53097033e-09+1.11688969e-07j
#    0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j]
#  [ 2.53097033e-09+1.11688969e-07j -7.07106917e-01-7.07106646e-01j
#    0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j]
#  [ 0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j
#   -7.07106917e-01-7.07106646e-01j  2.53097042e-09+1.11688969e-07j]
#  [ 0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j
#   -2.53097042e-09+1.11688969e-07j -7.07106917e-01+7.07106646e-01j]]

# %% [markdown]
# Apply the protocol shown in Fig. 1(b)
# $\begin{equation}
# U_1 = R_{z}(\pm\pi/2) \,\, X_{\rm cav}Z_2\,\, R_{z}(\mp\pi/2) = X_1 \otimes Z_2
# \end{equation}$
#
# This is the final gate:

# %%
qt.Qobj(U_sim_1[2:6, 2:6])
# Out:
# Quantum object: dims=[[4], [4]], shape=(4, 4), type='oper', dtype=Dense, isherm=False
# Qobj data =
# [[ 0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j
#    1.00000000e+00+9.40261793e-17j -3.57933347e-09+3.57933179e-09j]
#  [ 0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j
#   -3.57933347e-09-3.57933179e-09j -1.00000000e+00+8.37747490e-17j]
#  [ 1.00000000e+00-1.00914313e-15j  3.57933316e-09+3.57933210e-09j
#    0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j]
#  [ 3.57933316e-09-3.57933210e-09j -1.00000000e+00-1.05440285e-15j
#    0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j]]

# %%
#U_sim_1 = U_step_1[-1] * (Sz*X_cav) * U_step_1[-1]

fid_0 = tools.calculate_gate_fidelity(qt.Qobj(U_sim_1[2:6, 2:6]), (X_cav*Sz)[2:6, 2:6]) 
print(" ----------------- Infidelity ----------------\n")
print("             ", 1 - fid_0, "\n")
print(" ---------------------------------------------")

qt.Qobj(U_sim_1[2:6,2:6])
# Out:
#  ----------------- Infidelity ----------------
#
#               -1.865174681370263e-14
#
#  ---------------------------------------------
# Quantum object: dims=[[4], [4]], shape=(4, 4), type='oper', dtype=Dense, isherm=False
# Qobj data =
# [[ 0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j
#    1.00000000e+00+9.40261793e-17j -3.57933347e-09+3.57933179e-09j]
#  [ 0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j
#   -3.57933347e-09-3.57933179e-09j -1.00000000e+00+8.37747490e-17j]
#  [ 1.00000000e+00-1.00914313e-15j  3.57933316e-09+3.57933210e-09j
#    0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j]
#  [ 3.57933316e-09-3.57933210e-09j -1.00000000e+00-1.05440285e-15j
#    0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j]]

# %%
U_sim_1 = U_step_1_3[-1] * (Sz*X_cav) * U_step_1_3[-1]

fid_0 = tools.calculate_gate_fidelity(U_sim_1[6:8, 6:8], I)
print(" ----------------- Infidelity ----------------\n")
print("             ", 1 - fid_0, "\n")
print(" ---------------------------------------------")

qt.Qobj(U_sim_1[6:8, 6:8])
# Out:
#  ----------------- Infidelity ----------------
#
#               9.559020242022598e-14
#
#  ---------------------------------------------
# Quantum object: dims=[[2], [2]], shape=(2, 2), type='oper', dtype=Dense, isherm=False
# Qobj data =
# [[ 3.82973999e-07+1.00000000e+00j  1.57952024e-07-3.57933201e-09j]
#  [ 1.57952024e-07+3.57933201e-09j -3.82973999e-07+1.00000000e+00j]]

# %% [markdown]
# Now, let's put everything together and see how the joint parity gate (with ideal itermediate step 2) performs against the noise.

# %%
from scipy.linalg import block_diag

# Joint parity target: 1j*I on |00> and |11> sectors, X_cav*Z_t on code space
u_jp_target_a = block_diag(-1j*I.full(), (X_cav*Sz)[2:6, 2:6], 1j*I.full())   # 8x8 numpy array

u_jp_target_b = block_diag(-I.full(), (X_cav*Sz)[2:6, 2:6], I.full())         # 8x8 numpy array


fid_Ujp_noise_free = tools.calculate_gate_fidelity(U_sim_1.full(), u_jp_target_a)
print(" ----------------- Infidelity of Joint Parity ----------------\n")
print("             ", 1 - fid_Ujp_noise_free, "\n")
print(" ---------------------------------------------")
# Out:
#  ----------------- Infidelity of Joint Parity ----------------
#
#               5.739853037312059e-14
#
#  ---------------------------------------------

# %% [markdown]
# Next, we proceed by defining a more realistic approach for the $X_1\otimes Z_2$. To that end, we used [BARQ (arXiv:2503.11492)](https://arxiv.org/abs/2503.11492) and specifically [QURVEROS](https://github.com/evpiliouras/qurveros) package to obtain smooth and experimentally friendly pulses. For more information about the conditions and constaints see the main paper.

# %%
name = 'pulses/XZ_gate_gauss_and_barq.csv'                                                # name of the .csv file with the transmon fields


omega_x, omega_tr, phi_tr, delta_tr = np.loadtxt(name, delimiter=",").T    # load the fields on the variables

# normalized parameters
x_g = omega_x * chi                                                         # normalized control along X-axis FOR THE CAVITY. Gaussian pulse. See Fig. 3 (a)
y_g = np.zeros_like(omega_x)                                                # normalized control along Y-axis FOR THE CAVITY
z_g = np.zeros_like(omega_x)                                                # normalized control along Z-axis FOR THE CAVITY

# normalized parameters
x_tr = omega_tr * np.cos(phi_tr) * chi                                      # normalized control along X-axis   See Fig. 3 (b)                                      
y_tr = omega_tr * np.sin(phi_tr) * chi                                      # normalized control along Y-axis   See Fig. 3 (b)
z_tr = -delta_tr * chi                                                       # normalized control along Z-axis   See Fig. 3 (b)

time_g_tr      = np.linspace(0, 1/np.abs(chi), N_points)                            # time vector for X_1 Z_2 gate

H_g_tr = [[(a.dag()*b + a*b.dag())/2,    x_g ],
          [(n_a-n_b)*Sz/2,           -chi/2*0],  
          [Sx/2,                         x_tr], 
          [Sy/2,                         y_tr], 
          [Sz/2,                         z_tr]]         # Hamiltonian.  See Eq.(S32) in "Dynamical error reshaping for dual-rail erasure qubits"

H_g_tr = qt.QobjEvo(H_g_tr, tlist = time_g_tr)

result_g_tr = qt.propagator(H_g_tr, t = time_g_tr, args=None, options={'max_step': 0.5/N_points,'atol': 1e-14,'rtol': 1e-14})       # simulator

fid_g_tr = tools.calculate_gate_fidelity(qt.Qobj(result_g_tr[-1][2:6, 2:6]), (X_cav*Sz)[2:6, 2:6])   # code-space gate fidelity

print(" ----------------- Infidelity ----------------\n")
print("             ",1 - fid_g_tr, "\n")
print(" ---------------------------------------------")

U_XZ = result_g_tr[-1]                                                      # final gate

result_g_tr[-1]
# Out:
#  ----------------- Infidelity ----------------
#
#               3.248512570053208e-13
#
#  ---------------------------------------------
# Quantum object: dims=[[2, 2, 2], [2, 2, 2]], shape=(8, 8), type='oper', dtype=Dense, isherm=False
# Qobj data =
# [[ 5.83326714e-07+1.00000000e+00j -2.57693840e-11+1.62757053e-11j
#    0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j
#    0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j
#    0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j]
#  [ 2.57693840e-11+1.62757053e-11j  5.83326714e-07-1.00000000e+00j
#    0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j
#    0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j
#    0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j]
#  [ 0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j
#    3.53890869e-16-5.89364308e-15j -3.97434723e-16+2.55094157e-15j
# ...

# %% [markdown]
# When the system is in the code space $\{\ket{01},\ket{10}\}$, the joint parity gate yields to $X_1\otimes Z_2$ (with finite $g$ coupling) and in the absence of noise the fage fidelity is given below.

# %%
fid_1g = tools.calculate_gate_fidelity((U_step_1_3[-1]* result_g_tr[-1] * U_step_1_3[-1]).full(), u_jp_target_b)   
print(" ---------------------------------------------")
print("             ",1 - fid_1g, "\n")
print(" ---------------------------------------------")
# Out:
#  ---------------------------------------------
#               4.1722181265413383e-13
#
#  ---------------------------------------------

# %% [markdown]
# Now let's see how this responds to the noise.

# %%
noise_points = 50

gamma = np.logspace(-3,0, noise_points)                                         # noise parameter

gamma_over_chi = gamma * chi

fid_Ujp_Z_ZZ_robust_0photon  = np.zeros_like(gamma)                             # initialize array for later use
fid_Ujp_Z_ZZ_robust_1photon  = np.zeros_like(gamma)                             # initialize array for later use

fid_Ujp_sqr_pls_yale_0photon = np.zeros_like(gamma)                             # initialize array for later use                        
fid_Ujp_sqr_pls_yale_1photon = np.zeros_like(gamma)                             # initialize array for later use

fid_Ujp_Z_ZZ_full = np.zeros_like(gamma)                                        # initialize array for later use
fid_Ujp_sqr_full  = np.zeros_like(gamma)                                        # initialize array for later use


u_jp_full_target = qt.Qobj( block_diag(-1*I.full(), (X0*Z1).full()) )           # u_jp target for my robust gate    6x6

u_jp_full_sqr_target = qt.Qobj( block_diag( I.full(), 1j*Z1.full()) )           # U_jp target for yale sqr pulse    6x6


""" Dispersive coupling during the second step. See Eq. (S33) """

ksi = 0.0 * chi            # set this value to be {0., 0.01, 0.1, 0.5, 1.}        # cross-talk on step #2   <====================================



print("ZZ Crosstalk value is ξ/χ = ", ksi/chi)

for q in range(0,noise_points):

    # Rz(π/2) steps 1 & 3 (identical), full 8x8 Fock-space Hamiltonian -- same construction as cell[9]
    H_robust_step_1_3 = [[n_a * Sz,                   -(chi/2)],
                         [(a.dag()*b + a*b.dag())/2, g_control],
                         [Sx/2,                      x_control],
                         [Sy/2,                      y_control],
                         [Sz/2,                      z_control + gamma_over_chi[q]]]

    H_robust_step_1_3 = qt.QobjEvo(H_robust_step_1_3, tlist=time_gate_1_3)

    U_step_1_3 = qt.propagator(H_robust_step_1_3, t=time_gate_1_3, args=None,
                                  options={"max_step": 0.5/N_points, "atol": 1e-14, "rtol": 1e-14})

    # XZ gate, step 2, full 8x8 Fock-space Hamiltonian -- same construction as cell[16]
    H_g_tr = [[(a.dag()*b + a*b.dag())/2,        x_g ],
              [(n_a -n_b)* Sz/2,            -ksi/2 *0],
              [Sx/2,                             x_tr],
              [Sy/2,                             y_tr],
              [Sz/2,                       z_tr + gamma_over_chi[q]]]

    H_g_tr = qt.QobjEvo(H_g_tr, tlist = time_g_tr)

    result_g_tr = qt.propagator(H_g_tr, t = time_g_tr, args=None,
                                 options={'max_step': 0.5/N_points,'atol': 1e-14,'rtol': 1e-14})

    # combined joint-parity gate (step1 * step2 * step3), full 8x8 -- fidelity of the whole matrix only
    U_JP = U_step_1_3[-1] * result_g_tr[-1] * U_step_1_3[-1]

    fid_Ujp_Z_ZZ_full[q] = tools.calculate_gate_fidelity(U_JP.full(), u_jp_target_b)
    



# Square pulse Ujp -- full 8x8 Fock-space Hamiltonian, same construction as H_full in cell[3]
for q in range(0,noise_points):

    H_square_pulse = (g_chi/2) * (a.dag()*b + a*b.dag()) - (chi/2) * a.dag()*a * Sz + (gamma_over_chi[q]/2) * Sz     # H_full + ancilla dephasing noise

    U_JP_sqr_pls = qt.propagator(H_square_pulse, t=t_sqr_pls, options={'max_step': 0.5/N_points, 'atol': 1e-14, 'rtol': 1e-14})

    fid_Ujp_sqr_full[q] = tools.calculate_gate_fidelity(U_JP_sqr_pls[-1], U_sqr_pls[-1])          # fidelity of the full 8x8 matrix
# Out:
# ZZ Crosstalk value is ξ/χ =  0.0

# %% [markdown]
# Left figure shows the infidelity of the block-matrices/gates creating the larger one.
#
# Right figure shows the infidelity of the joint parity gate

# %%
fig = plt.figure(figsize=(6, 5))

ax = fig.add_subplot(111)

ax.plot(np.log10(gamma_over_chi / chi), np.log10( abs(1-fid_Ujp_Z_ZZ_full)), linewidth = 2, label = "Ujp - robust ")

ax.plot(np.log10(gamma_over_chi / chi), np.log10( abs(1-fid_Ujp_sqr_full)), linewidth = 2, label = "Ujp - sqr pls ")

ax.set_xlabel("Dephasing error, log10(γ/χ)")
ax.set_ylabel("Infidelity, log10(1-F)")
ax.set_title("Joint Parity")
ax.set_ylim([-12, 0])
ax.set_xlim([-3, 0])
ax.legend();

# fig.savefig("U_jp_dephasing_wrt_chi__step2_ksi_1chi.svg")

# %% [markdown]
# We go back to our main results and we test the dephasing and crosstalk robustness of the $X_1\otimes Z_2$ gate.

# %%
omega_x, omega_tr, phi_tr, delta_tr = np.loadtxt("pulses/XZ_gate_gauss_and_barq.csv", delimiter=",").T

t_0_1 = np.linspace(0,1, N_points)

# %% [markdown]
# Plot the control fields for transmon, see Fig. 3(b).

# %%
fig = plt.figure(figsize=(5, 5))

plt.plot(t_0_1, omega_tr, linewidth = 2)
plt.plot(t_0_1, omega_tr*np.cos(phi_tr))
plt.plot(t_0_1, omega_tr*np.sin(phi_tr))

plt.ylim([-26,26])

plt.xlabel("Time t*χ")
plt.ylabel("Pulse amplitude Ω/χ")
plt.title("Z pulse for cross-talk cancellation")
plt.legend();

# fig.savefig('gaussian_and_transmon_fields.svg')
# Out:
# /tmp/ipykernel_32058/163280273.py:12: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend();

# %%
t_0_1_chi = np.linspace(0,1/np.abs(chi), N_points)

# normalized parameters
x_gauss = omega_x * np.abs(chi)                                                         # normalized control along X-axis                                       
 

x_barq = omega_tr * np.cos(phi_tr) * np.abs(chi)                                        # normalized control along X-axis                                       
y_barq = omega_tr * np.sin(phi_tr) * np.abs(chi)                                        # normalized control along Y-axis
z_barq = delta_tr                  * np.abs(chi)                                        # normalized control along Z-axis



H_gauss_barq = [[(a.dag()*b + a*b.dag())/2,    x_gauss ],
                [(n_a -n_b)* Sz/2,            -chi/2 *0],  
                [Sx/2,                           x_barq], 
                [Sy/2,                           y_barq], 
                [Sz/2,                           z_barq]]      # Hamiltonian Eq. (S33) without noise

H_gauss_barq = qt.QobjEvo(H_gauss_barq, tlist=t_0_1_chi)

result_gauss_barq = qt.propagator(H_gauss_barq, t=t_0_1_chi, args=None, options={'max_step': 0.1/N_points,'atol': 1e-14,'rtol': 1e-14})

result_gauss_barq[-1]                   # X_1 Z_2 gate
# Out:
# Quantum object: dims=[[2, 2, 2], [2, 2, 2]], shape=(8, 8), type='oper', dtype=Dense, isherm=False
# Qobj data =
# [[ 5.83327303e-07+1.00000000e+00j  2.49526335e-11-1.47904065e-11j
#    0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j
#    0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j
#    0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j]
#  [-2.49526335e-11-1.47904065e-11j  5.83327303e-07-1.00000000e+00j
#    0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j
#    0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j
#    0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j]
#  [ 0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j
#   -5.82768724e-15-1.36139889e-12j -8.62153523e-16-8.54693869e-15j
#    1.00000000e+00-5.83327299e-07j -1.47886006e-11-2.49596844e-11j
#    0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j]
# ...

# %%
fid_gauss_barq = tools.calculate_gate_fidelity(result_gauss_barq[-1].full(), 
                                              block_diag(1j*Z.full(), (X_cav*Sz)[2:6, 2:6], 1j*Z.full()))      # Fidelity of X_1 Z_2 gate
print(" ----------------- Infidelity ----------------\n")
print("             ",1 - fid_gauss_barq, "\n")
print(" ---------------------------------------------")
# Out:
#  ----------------- Infidelity ----------------
#
#               3.468336728928989e-13
#
#  ---------------------------------------------

# %% [markdown]
# Let's test the robustness of the gate against $Z_2$ dephasing noise. The cell below reproduces Fig. 3(c).

# %%
noise_points = 50

gamma = np.logspace(-3, 0., noise_points)                              # noise parameter

gamma_over_chi = gamma * np.abs(chi)


fid_XZ         = np.zeros_like(gamma)                               # initialize array for later use
fid_non_robust = np.zeros_like(gamma)                               # initialize array for later use



ksi_over_chi = 0.0 * np.abs(chi)


print("ZZ crosstalk is set ξ/χ = ", ksi_over_chi/np.abs(chi))

# loop for robust gates
for q in range(0,noise_points):
 
    H_gauss_barq = [[(a.dag()*b + a*b.dag())/2,    x_gauss ],
                    [(n_a -n_b)* Sz/2,            -ksi_over_chi *0],  
                    [Sx/2,                           x_barq], 
                    [Sy/2,                           y_barq], 
                    [Sz/2,                    z_barq + gamma_over_chi[q]]] # Hamlitonian with \gamma *Tg * Z/2 noise ternm
                                                             

    H_gauss_barq = qt.QobjEvo(H_gauss_barq, tlist=t_0_1_chi)                                                                                 # quantum object

    result_XZ = qt.propagator(H_gauss_barq, t=t_0_1_chi, args=None, options={'max_step': 0.5/N_points,'atol': 1e-14,'rtol': 1e-14})       # run the simulator 

    fid_XZ[q] = np.abs(tools.calculate_gate_fidelity(result_XZ[-1].full(),
                                                     block_diag(1j*Z.full(), (X_cav*Sz)[2:6, 2:6], 1j*Z.full())))    


    # non ZZ robust gate.

    H_non_robust = [[X0/2, 3*np.pi * np.abs(chi)], 
                    [Z1/2, 9*np.pi * np.abs(chi) + gamma_over_chi[q]],
                    [Z0*Z1/2, ksi_over_chi]]

    H_non_robust = qt.QobjEvo(H_non_robust, tlist=t_0_1_chi)

    result_non_robust = qt.propagator(H_non_robust, t=t_0_1_chi, args=None, options={'max_step': 0.5/N_points,'atol': 1e-14,'rtol': 1e-14})

    fid_non_robust[q] = tools.calculate_gate_fidelity(result_non_robust[-1], X0*Z1)
# Out:
# ZZ crosstalk is set ξ/χ =  0.0

# %%
fig, ax = plt.subplots()
ax.plot(np.log10(gamma_over_chi / np.abs(chi)), np.log10( abs(1-fid_XZ)), linewidth = 2, label = "XZ DCG")
ax.plot(np.log10(gamma_over_chi / np.abs(chi)), np.log10( abs(1-fid_non_robust)), linewidth = 2, label = "XZ simple")

ax.set_xlabel("Dephasing error, log10(γ/χ)")
ax.set_ylabel("Infidelity, log10(1-F)")
ax.set_title("Z2 robustness")
ax.set_ylim([-15, 0])
ax.set_xlim([-3,  0])
ax.legend();

# %% [markdown]
# Let's do the same for the cross-talk robustness

# %%
noise_points = 50

ksi = np.logspace(-3,0, noise_points)                              # noise parameter

ksi_over_chi = ksi * np.abs(chi)

fid_XZ         = np.zeros_like(gamma)
fid_non_robust = np.zeros_like(gamma)

gamma_over_chi = 0.0 * np.abs(chi)


print("dephasing is set γ/χ = ", gamma_over_chi/chi)

# loop for robust gates
for q in range(0,noise_points):
 
    H_gauss_barq = [[(a.dag()*b + a*b.dag())/2,            x_gauss ],
                        [(n_a -n_b)* Sz/2,       -ksi_over_chi[q]/2],  
                        [Sx/2,                               x_barq], 
                        [Sy/2,                               y_barq], 
                        [Sz/2,                               z_barq]]                                                              # Hamlitonian with \gamma *Tg * Z/2 noise ternm

    H_gauss_barq = qt.QobjEvo(H_gauss_barq, tlist=t_0_1_chi)                                                                                 # quantum object

    result_XZ = qt.propagator(H_gauss_barq, t=t_0_1_chi, args=None, options={'max_step': 0.5/N_points,'atol': 1e-14,'rtol': 1e-14})       # run the simulator 

    fid_XZ[q] = np.abs(tools.calculate_gate_fidelity(result_XZ[-1].full(), 
                                                     block_diag(1j*Z.full(), (X_cav*Sz)[2:6, 2:6], 1j*Z.full())))      


    # non ZZ robust gate.

    H_non_robust = [[X0/2, 3*np.pi * chi], 
                    [Z1/2, 9*np.pi * chi + gamma_over_chi],
                    [Z0*Z1/2, ksi_over_chi[q]]]

    H_non_robust = qt.QobjEvo(H_non_robust, tlist=t_0_1_chi)

    result_non_robust = qt.propagator(H_non_robust, t=t_0_1_chi, args=None, options={'max_step': 0.5/N_points,'atol': 1e-14,'rtol': 1e-14})

    fid_non_robust[q] = tools.calculate_gate_fidelity(result_non_robust[-1], X0*Z1)
# Out:
# dephasing is set γ/χ =  -0.0

# %%
fig, ax = plt.subplots()
ax.plot(np.log10(ksi_over_chi / np.abs(chi)), np.log10( abs(1-fid_XZ)), linewidth = 2, label = "XZ DCG")
ax.plot(np.log10(ksi_over_chi / np.abs(chi)), np.log10( abs(1-fid_non_robust)), linewidth = 2, label = "XZ simple")

ax.set_xlabel("Dephasing error, log10(ξ/χ)")
ax.set_ylabel("Infidelity, log10(1-F)")
ax.set_title("ZZ robustness")
ax.set_ylim([-15, 0])
ax.set_xlim([-3,  0])
ax.legend();

# %% [markdown]
# Now we build the logical $CZ = ZZ_L(\pi/2)$ gate on the two dual-rail cavities, mediated by the shared transmon ancilla: two applications of the joint-parity gate $U_{\rm jp}$ (same construction as cells[9],[17]) sandwiched around an ancilla-only rotation $X(\theta=\pi/2)$, with $Y(\pm\pi/4)$ state-preparation gates on the ancilla before/after:
# $$CZ = Y(\pi/4)\, U_{\rm jp}\, X(\theta)\, U_{\rm jp}\, Y(-\pi/4)$$
#
# Since $X(\theta)$ and $Y(\pm\pi/4)$ act only on the transmon, they factorize as identity-on-cavities $\otimes$ rotation-on-transmon, so we build them directly in the full 8x8 Fock space -- no need to split into the $\ket{00}$, $\{\ket{01},\ket{10}\}$, $\ket{11}$ subspaces and stitch them back together.

# %%
III = qt.tensor(qt.qeye(N_fock), qt.qeye(N_fock), qt.qeye(2))               # 8x8 identity

# Joint parity gate U_jp = step1 . step2 . step3, full 8x8 Fock-space -- same construction as cells[9],[17], noise-free
# (recomputed here since U_step_1_3 / result_g_tr get overwritten by the robustness loop above)
H_robust_step_1_3 = [[n_a * Sz,                   -(chi/2)],
                     [(a.dag()*b + a*b.dag())/2, g_control],
                     [Sx/2,                      x_control],
                     [Sy/2,                      y_control],
                     [Sz/2,                      z_control]]

H_robust_step_1_3 = qt.QobjEvo(H_robust_step_1_3, tlist=time_gate_1_3)

U_step_1_3 = qt.propagator(H_robust_step_1_3, t=time_gate_1_3, args=None,
                              options={"max_step": 0.5/N_points, "atol": 1e-14, "rtol": 1e-14})

H_g_tr = [[(a.dag()*b + a*b.dag())/2,      x_g],
          [(n_a - n_b)*Sz/2,               0.0],
          [Sx/2,                          x_tr],
          [Sy/2,                          y_tr],
          [Sz/2,                          z_tr]]

H_g_tr = qt.QobjEvo(H_g_tr, tlist = time_g_tr)

result_g_tr = qt.propagator(H_g_tr, t = time_g_tr, args=None,
                             options={'max_step': 0.5/N_points,'atol': 1e-14,'rtol': 1e-14})

U_jp = U_step_1_3[-1] * result_g_tr[-1] * U_step_1_3[-1]

# Ancilla-only rotations: identity on both cavities, rotation on the transmon -- no subspace splitting needed
theta_zz = np.pi/2

X_theta_full = np.cos(theta_zz/2)*III - 1j*np.sin(theta_zz/2)*Sx

Y_pi_4_full       = np.cos(np.pi/4)*III + 1j*np.sin(np.pi/4)*Sy
Y_minus_pi_4_full = np.cos(np.pi/4)*III - 1j*np.sin(np.pi/4)*Sy

# CZ = Y(pi/4) . U_jp . X(theta) . U_jp . Y(-pi/4)
ZZ_L = Y_pi_4_full * U_jp * X_theta_full * U_jp * Y_minus_pi_4_full

ZZ_L
# Out:
# Quantum object: dims=[[2, 2, 2], [2, 2, 2]], shape=(8, 8), type='oper', dtype=Dense, isherm=False
# Qobj data =
# [[ 7.07106558e-01-7.07107005e-01j  5.02549843e-09+2.83341485e-07j
#    0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j
#    0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j
#    0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j]
#  [-5.02549840e-09+2.83341484e-07j  7.07106558e-01+7.07107005e-01j
#    0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j
#    0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j
#    0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j]
#  [ 0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j
#    7.07106781e-01+7.07106781e-01j  5.02550236e-09+8.24948428e-07j
#   -5.28361446e-21+5.30927173e-21j  3.60757688e-15+8.33487066e-15j
#    0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j]
# ...

# %%
ZZ_L_sqr_pls = Y_pi_4_full * U_sqr_pls[-1] * X_theta_full * U_sqr_pls[-1] * Y_minus_pi_4_full

# %% [markdown]
# Now let's test the robustness of $ZZ_L$ against ancilla dephasing, using the same full 8x8 Hamiltonians as above (noise enters the same way it does everywhere else in the notebook: added to the $S_z$ coefficient).

# %%
noise_points = 50

gamma = np.logspace(-3, 0, noise_points)                              # noise parameter
gamma_over_chi = gamma * np.abs(chi)

ksi_values = np.array([0., 0.1, 0.5, 1.]) * np.abs(chi)               # cross-talk values to sweep on step #2

fid_Ujp    = np.zeros((len(ksi_values), noise_points))
fid_ZZ_L   = np.zeros((len(ksi_values), noise_points))

ZZ_L_target = ZZ_L                                                    # noise-free CZ gate computed above

for k, ksi in enumerate(ksi_values):

    print("Cross-talk value is ξ/χ = ", ksi/np.abs(chi))

    for q in range(0, noise_points):

        # Rz(π/2) steps 1 & 3, full 8x8 Fock-space Hamiltonian -- same construction as cell[9]
        H_robust_step_1_3 = [[n_a * Sz,                           -(chi/2)],
                             [(a.dag()*b + a*b.dag())/2,         g_control],
                             [Sx/2,                              x_control],
                             [Sy/2,                              y_control],
                             [Sz/2,          z_control + gamma_over_chi[q]]]

        H_robust_step_1_3 = qt.QobjEvo(H_robust_step_1_3, tlist=time_gate_1_3)

        U_step_1_3 = qt.propagator(H_robust_step_1_3, t=time_gate_1_3, args=None,
                                      options={"max_step": 0.5/N_points, "atol": 1e-14, "rtol": 1e-14})

        # XZ gate, step 2, full 8x8 Fock-space Hamiltonian -- same construction as cell[17]
        H_g_tr = [[(a.dag()*b + a*b.dag())/2,                 x_g ],
                  [(n_a - n_b)*Sz/2,                        -ksi/2],
                  [Sx/2,                                      x_tr],
                  [Sy/2,                                      y_tr],
                  [Sz/2,                  z_tr + gamma_over_chi[q]]]

        H_g_tr = qt.QobjEvo(H_g_tr, tlist = time_g_tr)

        result_g_tr = qt.propagator(H_g_tr, t = time_g_tr, args=None,
                                     options={'max_step': 0.5/N_points,'atol': 1e-14,'rtol': 1e-14})

        U_jp_noisy = U_step_1_3[-1] * result_g_tr[-1] * U_step_1_3[-1]

        ZZ_L_noisy = Y_pi_4_full * U_jp_noisy * X_theta_full * U_jp_noisy * Y_minus_pi_4_full

        fid_Ujp[k,q]  = np.abs(tools.calculate_gate_fidelity(U_jp_noisy.full(), u_jp_target_b))

        fid_ZZ_L[k, q] = np.abs(tools.calculate_gate_fidelity(ZZ_L_noisy.full(), ZZ_L_target.full()))


# Square-pulse baseline -- no crosstalk term, so just a single sweep over gamma
fid_Ujp_sqr_pls  = np.zeros(noise_points)
fid_ZZ_L_sqr_pls = np.zeros(noise_points)

for q in range(0, noise_points):

    H_square_pulse = (g_chi/2) * (a.dag()*b + a*b.dag()) - (chi/2) * a.dag()*a * Sz + (gamma_over_chi[q]/2) * Sz

    U_JP_sqr_pls = qt.propagator(H_square_pulse, t=t_sqr_pls, options={'max_step': 0.5/N_points, 'atol': 1e-14, 'rtol': 1e-14})

    U_jp_sqr_pls_noisy = U_JP_sqr_pls[-1]

    ZZ_L_sqr_pls_noisy = Y_pi_4_full * U_jp_sqr_pls_noisy * X_theta_full * U_jp_sqr_pls_noisy * Y_minus_pi_4_full

    fid_Ujp_sqr_pls[q]  = np.abs(tools.calculate_gate_fidelity(U_jp_sqr_pls_noisy.full(), U_sqr_pls[-1].full()))

    fid_ZZ_L_sqr_pls[q] = np.abs(tools.calculate_gate_fidelity(ZZ_L_sqr_pls_noisy.full(), ZZ_L_sqr_pls.full()))
# Out:
# Cross-talk value is ξ/χ =  0.0
# Cross-talk value is ξ/χ =  0.1
# Cross-talk value is ξ/χ =  0.5
# Cross-talk value is ξ/χ =  1.0

# %%
import matplotlib.colors as mcolors


fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 5))

for k, ksi in enumerate(ksi_values):
    ax1.plot(np.log10(gamma_over_chi / np.abs(chi)), np.log10( abs(1-fid_Ujp[k])),  linewidth = 2, label = f"ξ/χ = {ksi/np.abs(chi):.2g}")
    ax2.plot(np.log10(gamma_over_chi / np.abs(chi)), np.log10( abs(1-fid_ZZ_L[k])), linewidth = 2,  label = f"ξ/χ = {ksi/np.abs(chi):.2g}")

ax1.plot(np.log10(gamma_over_chi / np.abs(chi)), np.log10( abs(1-fid_Ujp_sqr_pls)),  linewidth = 2, linestyle = '--', color = 'k', label = "sqr pls")
ax2.plot(np.log10(gamma_over_chi / np.abs(chi)), np.log10( abs(1-fid_ZZ_L_sqr_pls)), linewidth = 2, linestyle = '--', color = 'k', label = "sqr pls")

ax1.set_xlabel("Dephasing error, log10(γ/χ)")
ax1.set_ylabel("Infidelity, log10(1-F)")
ax1.set_title("Joint Parity (Ujp)")
ax1.set_ylim([-13, 0])
ax1.set_xlim([-3, 0])
ax1.legend();

ax2.set_xlabel("Dephasing error, log10(γ/χ)")
ax2.set_ylabel("Infidelity, log10(1-F)")
ax2.set_title("ZZ_L(pi/2)")
ax2.set_ylim([-13, 0])
ax2.set_xlim([-3, 0])
ax2.legend();

# fig.savefig("ZZ_L_dephasing_wrt_chi__step2_ksi_1chi.svg")
